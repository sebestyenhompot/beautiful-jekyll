# %%
import pandas as pd
xl = pd.ExcelFile("C:\\Users\Siming\Documents\WDDH Project\AA_hokkien2\Hokkien_spreadsheets_by_Sebestyen_Hompot.xlsx") # Fill in the path to your own excel file here!
print(xl)

# %%
print(xl.sheet_names)
# Out:
# ['countries', 'cities', 'missionary_societies', 'publishers', 'people', 'transcription_methods', 'publications', 'pub_author']

# %%
df_ctr = xl.parse('countries')
df_cit = xl.parse('cities')
df_mis = xl.parse('missionary_societies')
df_pbr = xl.parse('publishers')
df_ppl = xl.parse('people')
df_tra = xl.parse('transcription_methods')
df_pub = xl.parse('publications')
df_pau = xl.parse('pub_author')

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:Siming91@localhost:3306/hokkien')

# %%
import pymysql
cnx = pymysql.connect(host='localhost',
                      user='root',
                      password='Siming91',
                      db='hokkien',
                      charset='utf8mb4',
                      cursorclass=pymysql.cursors.DictCursor)
cursor = cnx.cursor()

# %%
df_ctr.to_sql(
    name='countries',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_cit.to_sql(
    name='cities',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_mis.to_sql(
    name='missionary_societies',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_pbr.to_sql(
    name='publishers',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_ppl.to_sql(
    name='people',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_tra.to_sql(
    name='transcription_methods',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_pub.to_sql(
    name='publications',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
df_pau.to_sql(
    name='pub_author',
    con=engine,
    index=False,
    if_exists='append'
)

# %%
# For checking out:
query = 'SELECT * FROM publications'
cursor.execute(query)
cursor.fetchall()
# Out:
# [{'city_pub': None,
#   'country_pub': None,
#   'digitized_at': None,
#   'id': 1,
#   'language': 'Spanish',
#   'mentioned_in': 'mentioned in Klöter 2010. The Language of the Sangleys ref. to González 1955.',
#   'paper_version_available_at': None,
#   'publisher': None,
#   'title_asianchar': None,
#   'title_orig': '[16-17th centuries Spanish manuscripts mentioned in Gonzalez 1955. Historia de las Misiones Dominicanas en China Vol. 1., by authors Miguel de Benavides, Victorio Riccio etc.]',
#   'title_translated': None,
#   'transcription_method': None,
#   'type': 'manuscript',
#   'year_pub': 1600},
#  {'city_pub': None,
#   'country_pub': 9,
#   'digitized_at': None,
#   'id': 2,
#   'language': 'Spanish',
#   'mentioned_in': 'Klöter, Henning 2010. The Language of the Sangleys p. 56.',
#   'paper_version_available_at': 'Biblioteca Angelica, Rome',
#   'publisher': 39,
#   'title_asianchar': None,
#   'title_orig': 'Dictionarium Sino-Hispanicum',
# ...
